# %%
import seaborn as sns
sns.set_style('ticks')

# %%
# %matplotlib inline

# %%
WTapouP_angles = []
for f in glob('WTapouP/*dat'):
    a = np.loadtxt(f, skiprows=1, usecols=1)
    WTapouP_angles.append(a)

# %%
glob('WTapouP/*dat')
# Out:
# ['WTapouP/my-cTnI-angle.dat',
#  'WTapouP/my-cTnT-angle-H1-H2.dat',
#  'WTapouP/my-cTnT-angle-H2-T2.dat',
#  'WTapouP/schwartz-cTnI-angle.dat',
#  'WTapouP/schwartz-cTnT-angle-H1-H2.dat',
#  'WTapouP/schwartz-cTnT-angle-H2-T2.dat']

# %%
f, (ax, ax2, ax3) = plt.subplots(1, 3, figsize=figure_dims(1200, 1))
c = ax.hexbin(WTapouP_angles[0], WTapouP_angles[1], mincnt=1, bins='log', cmap='magma')
sns.despine()
plt.colorbar(c, label='$\log_{10} N$', ax=ax)
ax.set(xlabel='cTnI angle', ylabel='cTnT H1-H2 angle', title='WT apo uP')


c2 = ax2.hexbin(WTapouP_angles[0], WTapouP_angles[2], mincnt=1, bins='log', cmap='magma')
plt.colorbar(c2, label='$\log_{10} N$', ax=ax2)
ax2.set(xlabel='cTnI angle', ylabel='cTnT H2-T2 angle', title='WT apo uP')


c3 = ax3.hexbin(WTapouP_angles[1], WTapouP_angles[2], mincnt=1, bins='log', cmap='magma')
plt.colorbar(c3, label='$\log_{10} N$', ax=ax3)
ax3.set(xlabel='cTnT H1-H2 angle', ylabel='cTnT H2-T2 angle', title='WT apo uP')

f.tight_layout()

# %%
data = np.stack([angles[0], angles[1]]).T

# %%
"""Plot RMSD results

msmbuilder autogenerated template version 2
created 2017-07-03T15:49:19.699572
please cite msmbuilder in any publications
"""

import numpy as np
from matplotlib import pyplot as plt
from msmexplorer import plot_trace
from msmbuilder.io import load_trajs
from matplotlib.ticker import FuncFormatter
from plot_utils import cleanup_top_right_axes
from cycler import cycler
from random import shuffle
import pandas as pd
from plot_utils import figure_dims
import matplotlib.gridspec as gridspec
import seaborn.apionly as sns
import matplotlib.patches as mpatches
sns.set_style('ticks')
colors = ["#cfa0ce",
          "#63db56",
          "#7941cf",
          "#b4e741",
          "#ce51c1",
          "#cecf3c",
          "#4f2b7f",
          "#629f3b",
          "#7879d7",
          "#d7a835",
          "#36203a",
          "#b4d97f",
          "#da487a",
          "#69dca1",
          "#e14733",
          "#79d6d9",
          "#9c392b",
          "#76a3c9",
          "#d57b38",
          "#555e85",
          "#d6c37b",
          "#8c3964",
          "#47682a",
          "#d38580",
          "#53987d",
          "#603728",
          "#cdd0b9",
          "#2d4334",
          "#917333",
          "#8d8271"]

def wrapAngle(x):
    x = (x+180) % 360
    if x < 0:
        x += 360
    return x - 180

def constrainAngle(x):
    x = x % 360
    if x < 0:
        x += 360
    return x

def plot_angle(data, N=50, title=None, ax1=None, ax2=None, color=None, wrap=True):
    if ax1 is None or ax2 is None:
        gs = gridspec.GridSpec(2, 6)
        ax1 = plt.subplot(gs[:1, :2], polar=True)
        ax2 = plt.subplot(gs[:1, 2:])

    if wrap:
        vf = np.vectorize(wrapAngle)        
    else:
        vf = np.vectorize(constrainAngle)
    x = vf(data)
    

    sns.distplot(x, bins=N, ax=ax2, color=color, kde=False)
    radii, theta = np.histogram(x, bins=N, normed=True)
    ax1.set_yticklabels([])

    if wrap:
        ax1.set_xticklabels(['{}°'.format(x) for x in [0, 45, 90, 135, 180, -135, -90, -45]])
        ax2.set_xticklabels(['{}°'.format(x) for x in [-180, -135, -90, -45, 0, 45, 90, 135, 180]])
    else:
        ax2.set_xticklabels(['{}°'.format(x) for x in [0, 45, 90, 135, 180, 225, 270, 315, 360]])
    
    ax2.set_yticks([])
    ax2.set(xlabel='Angle', ylabel='Density')
    cleanup_top_right_axes(ax2)

    width = (2 * np.pi) / N

    
    bars = ax1.bar(np.deg2rad(theta[1:]), radii, width=width, color=color, alpha=.5)

    if title is not None:
        plt.suptitle(title)

    plt.tight_layout()

    f = plt.gcf()
    return f, (ax1, ax2)

# %%
np.random.seed(42)

# %%
a = np.random.normal(45, size=1000)

# %%
plot_angle(a, wrap=False, N=50)
# Out:
# (<matplotlib.figure.Figure at 0x127130470>,
#  (<matplotlib.axes._subplots.PolarAxesSubplot at 0x127068470>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x12715e710>))

# %%
sns.distplot(np.vectorize(constrainAngle)(a))
sns.distplot(a)

# %%
plot_angle(a, wrap=True, N=50)
# Out:
# (<matplotlib.figure.Figure at 0x1277bf470>,
#  (<matplotlib.axes._subplots.PolarAxesSubplot at 0x1276c7be0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1277f3e80>))

# %%
plot_angle(WTapouP_angles[2]);

# %%
plot_angle(WTapouP_angles[2], wrap=False);

# %%
a = WTapouP_angles[2]

# %%
r, t  = np.histogram(a, normed=True, bins=50)

# %%
t * np.pi / 180
# Out:
# array([ 0.00501259,  0.04561254,  0.08621249,  0.12681245,  0.1674124 ,
#         0.20801235,  0.24861231,  0.28921226,  0.32981222,  0.37041217,
#         0.41101212,  0.45161208,  0.49221203,  0.53281198,  0.57341194,
#         0.61401189,  0.65461185,  0.6952118 ,  0.73581175,  0.77641171,
#         0.81701166,  0.85761161,  0.89821157,  0.93881152,  0.97941148,
#         1.02001143,  1.06061138,  1.10121134,  1.14181129,  1.18241125,
#         1.2230112 ,  1.26361115,  1.30421111,  1.34481106,  1.38541101,
#         1.42601097,  1.46661092,  1.50721088,  1.54781083,  1.58841078,
#         1.62901074,  1.66961069,  1.71021064,  1.7508106 ,  1.79141055,
#         1.83201051,  1.87261046,  1.91321041,  1.95381037,  1.99441032,
#         2.03501027])

# %%
plt.hist(a)
# Out:
# (array([  1132.,   5007.,  13664.,  18013.,  17277.,  51149.,  55368.,
#          19751.,   5968.,    519.]),
#  array([   0.2872 ,   11.91823,   23.54926,   35.18029,   46.81132,
#           58.44235,   70.07338,   81.70441,   93.33544,  104.96647,
#          116.5975 ]),
#  <a list of 10 Patch objects>)

# %%
np.histogram(a)
# Out:
# (array([ 1132,  5007, 13664, 18013, 17277, 51149, 55368, 19751,  5968,   519]),
#  array([   0.2872 ,   11.91823,   23.54926,   35.18029,   46.81132,
#           58.44235,   70.07338,   81.70441,   93.33544,  104.96647,
#          116.5975 ]))

# %%
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, projection='polar')
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.5)
    
    
ax.vlines(np.deg2rad(-45), 0, radii.max(), lw=3)

plt.show()

# %%
np.deg2rad(-45)
# Out:
# -0.78539816339744828

# %%
np.deg2rad(315)
# Out:
# 5.497787143782138

# %%
np.unwrap([5.49])
# Out:
# array([ 5.49])

# %%
wrapAngle(3)
# Out:
# 3

# %%
for x in range(1200):
    if x != constrainAngle(x):
        print(x)
# Out:
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# 525
# ...

# %%
constrainAngle(45)
# Out:
# 45
